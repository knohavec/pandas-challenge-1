# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#        client_id     order_id  order_week  order_year  unit_price  unit_cost  \
# count  54,639.00    54,639.00   54,639.00   54,639.00   54,639.00  54,639.00
# mean   54,837.87 5,470,190.03       11.36    2,022.99      136.27      99.45
# std    25,487.44 2,599,806.93        7.02        0.08      183.87     133.16
# min    10,033.00 1,000,886.00        1.00    2,022.00        0.01       0.01
# 25%    33,593.00 3,196,372.00        6.00    2,023.00       20.80      14.84
# 50%    53,305.00 5,496,966.00       11.00    2,023.00       68.31      49.89
# 75%    78,498.00 7,733,869.00       17.00    2,023.00      173.16     125.57
# max    99,984.00 9,998,480.00       52.00    2,023.00    1,396.23     846.27
#
#        unit_weight          qty  line_number
# count    54,639.00    54,639.00    54,639.00
# mean          5.00       570.26         2.98
# std           5.33    18,795.52         2.44
# min           0.00         0.00         0.00
# 25%           1.45        32.00         1.00
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

# %%
# What three item categories had the most entries?
top_categories = df['category'].value_counts().head(3)
top_categories
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
category_filter = df[df['category'] == 'consumables']
# category_filter.head()
# counts = category_filter['subcategory'].value_counts()
# counts.head()
top_subcategory = category_filter['subcategory'].value_counts().idxmax()
print(f"The top subcategory for the category with the most entries (consumables) is : {top_subcategory}")
# Out:
# The top subcategory for the category with the most entries (consumables) is : bathroom supplies

# %%
# Which five clients had the most entries in the data?
most_entries = df[['first','last','client_id']].value_counts().head(5)
print(f"The 5 clients with the most entries in the data are")
most_entries
# Out:
# The 5 clients with the most entries in the data are
# first      last     client_id
# Jessica    Reyes    33615        220
# Angela     Everett  66037        211
# Bryan      Myers    46820        209
# Kendra     Garrett  24741        207
# Alexandra  Young    38378        207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
client_id_list = df['client_id'].value_counts().head(5).index.tolist()
client_id_list
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the
# client with the most entries order order?
total_units = df.loc[df['client_id'] == 33615]['qty'].sum()
# total_units
print(f"The client with the most entries (Jessica Reyes) ordered {total_units} units")
# Out:
# The client with the most entries (Jessica Reyes) ordered 64313 units

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty
df['subtotal'] = df['unit_price']*df['qty']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.

df['shipping_price'] = df.apply(lambda row: 7 * row['unit_weight'] * row['qty'] if (row['unit_weight'] * row['qty']) > 50 else 10 * row['unit_weight'] * row['qty'], axis=1)
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

df['line_price'] = df['subtotal'] + df['shipping_price'] + ((df['subtotal'] + df['shipping_price']) * 0.0925)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).

df['cost'] = df['unit_cost']*df['qty'] + df['shipping_price']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
df['profit'] = df['line_price'] - df['cost']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
order_totals = df.groupby('order_id')['line_price'].sum()

specified_order_ids = [2742071, 2173913, 6128929]

specified_order_totals = order_totals.loc[specified_order_ids]

specified_order_totals
# Out:
# order_id
# 2742071   152,811.90
# 2173913   162,388.72
# 6128929   923,441.24
# Name: line_price, dtype: float64

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.
pd.options.display.float_format = '{:,.2f}'.format
top_5_spending = df[df['client_id'].isin(client_id_list)].groupby('client_id')['line_price'].sum()
top_5_spending.head()
# Out:
# client_id
# 24741   82,268,891.98
# 33615    8,377,308.57
# 38378   12,906,550.88
# 46820    9,743,794.32
# 66037   10,259,514.80
# Name: line_price, dtype: float64

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.
summary_df = df[df['client_id'].isin(client_id_list)].groupby('client_id').agg({'qty':'sum', 'shipping_price':'sum', 'line_price':'sum', 'profit':'sum'}).sort_values('profit', ascending=False)
summary_df.head()
# Out:
#               qty  shipping_price    line_price        profit
# client_id
# 24741      239862    5,126,448.37 82,268,891.98 36,579,992.27
# 38378       73667    3,429,455.40 12,906,550.88  3,271,829.90
# 66037       43018    1,395,151.85 10,259,514.80  3,255,031.82
# 46820       75768    1,601,448.84  9,743,794.32  2,736,602.68
# 33615       64313    1,828,984.89  8,377,308.57  2,201,994.66

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

def convert_to_millions(column):
    return (column/1000000)


summary_df[['shipping_price', 'line_price', 'profit']] = summary_df[['shipping_price', 'line_price', 'profit']].apply(convert_to_millions)

names = { 'qty': 'Total Units Purchased', 'shipping_price': 'Total Shipping Price (Millions of Dollars)', 'line_price': 'Total Revenue (Millions of Dollars)', 'profit': 'Total Profit (Millions of Dollars)'}
summary_df.rename(columns=names, inplace=True)
summary_df.head()
# Out:
#            Total Units Purchased  Total Shipping Price (Millions of Dollars)  \
# client_id
# 24741                     239862                                        5.13
# 38378                      73667                                        3.43
# 66037                      43018                                        1.40
# 46820                      75768                                        1.60
# 33615                      64313                                        1.83
#
#            Total Revenue (Millions of Dollars)  \
# client_id
# 24741                                    82.27
# 38378                                    12.91
# 66037                                    10.26
# 46820                                     9.74
# 33615                                     8.38
#
#            Total Profit (Millions of Dollars)
# client_id
# 24741                                   36.58
# 38378                                    3.27
# ...

# %%
# Sort the updated data by "Total Profit" form highest to lowest
summary_df.sort_values('Total Profit (Millions of Dollars)', ascending=False, inplace=True)
summary_df.head()
# Out:
#            Total Units Purchased  Total Shipping Price (Millions of Dollars)  \
# client_id
# 24741                     239862                                        5.13
# 38378                      73667                                        3.43
# 66037                      43018                                        1.40
# 46820                      75768                                        1.60
# 33615                      64313                                        1.83
#
#            Total Revenue (Millions of Dollars)  \
# client_id
# 24741                                    82.27
# 38378                                    12.91
# 66037                                    10.26
# 46820                                     9.74
# 33615                                     8.38
#
#            Total Profit (Millions of Dollars)
# client_id
# 24741                                   36.58
# 38378                                    3.27
# ...

# %% [markdown]
# ### Summary
# Client 24741 produces the most revenue for the company by far, at 36.58 million, while no other client had more than 3.27 million in revenue. This is likely because that client also had almost 3 times as many units purchesed when compared to the client with the next most units. Client 66037 orderecd signifigantly less units than other clients, but still had the 3rd most revenue at 3.26 million, indicating they are buying more expensive units.
